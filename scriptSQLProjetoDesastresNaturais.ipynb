-- %% [markdown]
-- # [ProjetoBD_DesastresNaturais]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [ProjetoBD_DesastresNaturais]    Script Date: 02/12/2023 17:08:02 ******/
CREATE DATABASE [ProjetoBD_DesastresNaturais]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'ProjetoBD_DesastresNaturais', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\ProjetoBD_DesastresNaturais.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'ProjetoBD_DesastresNaturais_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\ProjetoBD_DesastresNaturais_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [ProjetoBD_DesastresNaturais].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ARITHABORT OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET  DISABLE_BROKER 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET RECOVERY FULL 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET  MULTI_USER 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET DB_CHAINING OFF 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET DELAYED_DURABILITY = DISABLED 
GO
EXEC sys.sp_db_vardecimal_storage_format N'ProjetoBD_DesastresNaturais', N'ON'
GO
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Morador]

-- %%
USE [ProjetoBD_DesastresNaturais]
GO

-- %%
/****** Object:  Table [dbo].[Morador]    Script Date: 02/12/2023 17:08:02 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Morador](
	[CPF] [nchar](11) NOT NULL,
	[RG] [char](9) NULL,
	[Nome] [varchar](15) NOT NULL,
	[Sobrenome] [varchar](50) NULL,
	[Rua] [varchar](50) NULL,
	[Bairro] [varchar](50) NULL,
	[Numero] [int] NULL,
	[Complemento] [varchar](50) NULL,
 CONSTRAINT [PK_Morador] PRIMARY KEY CLUSTERED 
(
	[CPF] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ROAnterior]

-- %%
/****** Object:  Table [dbo].[ROAnterior]    Script Date: 02/12/2023 17:08:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ROAnterior](
	[idRO] [nchar](10) NOT NULL,
	[idROAnterior] [nchar](10) NOT NULL,
 CONSTRAINT [PK_ROAnterior] PRIMARY KEY CLUSTERED 
(
	[idRO] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TecnicosEnvolvidos]

-- %%
/****** Object:  Table [dbo].[TecnicosEnvolvidos]    Script Date: 02/12/2023 17:08:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TecnicosEnvolvidos](
	[Nome] [nchar](10) NOT NULL,
 CONSTRAINT [PK_TecnicosEnvolvidos] PRIMARY KEY CLUSTERED 
(
	[Nome] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Telefone]

-- %%
/****** Object:  Table [dbo].[Telefone]    Script Date: 02/12/2023 17:08:03 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Telefone](
	[CPFMorador] [nchar](11) NOT NULL,
	[Numero] [nchar](11) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Morador_Morador]

-- %%
ALTER TABLE [dbo].[Morador]  WITH CHECK ADD  CONSTRAINT [FK_Morador_Morador] FOREIGN KEY([CPF])
REFERENCES [dbo].[Morador] ([CPF])
GO
ALTER TABLE [dbo].[Morador] CHECK CONSTRAINT [FK_Morador_Morador]
GO

-- %% [markdown]
-- # [FK_Telefone_Morador]

-- %%
ALTER TABLE [dbo].[Telefone]  WITH CHECK ADD  CONSTRAINT [FK_Telefone_Morador] FOREIGN KEY([CPFMorador])
REFERENCES [dbo].[Morador] ([CPF])
GO
ALTER TABLE [dbo].[Telefone] CHECK CONSTRAINT [FK_Telefone_Morador]
GO

-- %% [markdown]
-- # [ProjetoBD_DesastresNaturais]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [ProjetoBD_DesastresNaturais] SET  READ_WRITE 
GO
